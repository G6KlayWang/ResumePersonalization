# %% [markdown]
# ## Sampling the resume data

# %%
# Define file paths
input_file = "resume_samples/resume_samples.txt"  # Replace with the path to your input file
output_file = "first_600_resumes.txt"  # Path for the output file

def extract_first_600_lines(input_file, output_file):
    try:
        # Open the input file for reading
        with open(input_file, 'r', encoding='latin-1') as infile:
            # Read all lines and limit to the first 600
            lines = infile.readlines()[:600]
        
        # Write the first 600 lines to the output file
        with open(output_file, 'w', encoding='latin-1') as outfile:
            outfile.writelines(lines)
        
        print(f"Successfully extracted the first 600 lines to {output_file}")
    except FileNotFoundError:
        print(f"Error: File {input_file} not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Call the function
extract_first_600_lines(input_file, output_file)
# Out:
# Successfully extracted the first 600 lines to first_600_resumes.txt

# %% [markdown]
# ## Resume data storage processing

# %%
import pandas as pd

# File paths
input_file = "first_600_resumes.txt"  # Path to your input text file
output_file = "resumes_output.csv"  # Path to save the output CSV

def process_resumes(input_file, output_file):
    data = []
    
    try:
        with open(input_file, 'r', encoding='latin-1') as file:
            for i, line in enumerate(file):
                # Split the line into parts based on the delimiter ":::"
                parts = line.strip().split(":::")
                
                # Ensure there are at least 3 parts to avoid errors
                if len(parts) < 3:
                    continue
                
                # Extract the third field (resume content)
                resume_content = parts[2]
                
                # Append to the data list as a tuple of (id, resume_content)
                data.append((i + 1, resume_content))  # Line numbers start from 1
        
        # Create a DataFrame from the data list
        df = pd.DataFrame(data, columns=["id", "resume_content"])
        
        # Save the DataFrame to a CSV file
        df.to_csv(output_file, index=False, encoding='latin-1')
        print(f"Successfully processed and saved to {output_file}")
    
    except FileNotFoundError:
        print(f"Error: File {input_file} not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Call the function
process_resumes(input_file, output_file)
# Out:
# Successfully processed and saved to resumes_output.csv

# %%
import pandas as pd
df = pd.read_csv("resumes_output.csv", encoding='latin-1')
df["resume_content"][0]
# Out:
# 'Database Administrator <span class="hl">Database</span> <span class="hl">Administrator</span> Database Administrator - Family Private Care LLC Lawrenceville, GA A self-motivated Production SQL Server Database Administrator who possesses\xa0 strong analytical and problem solving skills. My experience includes SQL Server\xa0 2005, 2008 and 2012, 2014, SSIS, as well as clustering, mirroring, and high\xa0 availability solutions in OLTP environments. I am proficient in database backup,\xa0 recovery, performance tuning, maintenance tasks, security, and consolidation.\xa0 I am confident that I would make a beneficial addition to any company. Over the\xa0 course of my career thus far, I have designed databases to fit a variety of needs,\xa0 successfully ensured the security of those databases, problem-solved in order to meet\xa0 both back-end and front-end needs, installed and tested new versions database\xa0 management systems, customized and installed applications and meticulously\xa0 monitored performance for the smoothest front-end experience possible. During my\xa0 5 to 6 years working with databases. Work Experience Database Administrator Family Private Care LLC - Roswell, GA April 2017 to Present Confirm that backups have been made and successfully saved to a secure\xa0 location\xa0 Planning for backup and recovery of database information.\xa0 Maintaining archived data Backing up and restoring databases, Contacting\xa0 database vendor for technical support Generating various reports by querying from database as per needed.\xa0 Managing and monitoring data replication. Acting as liaison with users High\xa0 Availability or Disaster Recovery Logs - Check your high availability and/or disaster recovery process logs. Depending on the solution (Log Shipping,\xa0 Clustering, Replication, Database Mirroring, CDP, etc.) that you are using\xa0 dictates what needs to be checked. Correcting errors and make necessary\xa0 modification\xa0 Modify existing databases and database management systems or direct\xa0 programmers and analysts to make changes.\xa0 Work as part of a project team to coordinate database development and see\xa0 termite project scope and limitations\xa0 Train Users and answers questions.\xa0 Approve, schedule, plan, and supervise the installation and testing of new\xa0 products and improvements to computer systems, such as the installation of new databases.\xa0 Review Procedures in Database management system manuals for making\xa0 changes to database.\xa0 Select and enter codes to monitor database performance and to create\xa0 production database.\xa0 Check the backup failure alerts, correct the errors and rerun the backups.\xa0 Review the average duration of backup, any significant changes occurred\xa0 investigates on this.\xa0 Most of the time it happens due to networking low bandwidth Validate the backup files using restore verify only.\xa0 I create jobs to take care of the task and to send a notification if it fails to verify\xa0 any backup.\xa0 Monitoring all backup and log history is cleaning when designed. Find out the newly added databases and define the backup plan. I do verify the free space on\xa0 each drive on all servers, If there is significant variance in free space from the day before, research the cause of the free space fluctuation and resolve if\xa0 necessary, Often times, log files will grow because of monthly jobs automate through a job. The job runs for every one hour and reports any drive which is\xa0 having less than 15 % of free space.\xa0 I can design a SSRS report to showcase and review the delta values.\xa0 Confirm all servers/databases are up and running fine. Usually in an Enterprise\xa0 Database Environment Third Party Tools are used to monitor Servers. For\xa0 database monitoring, I can design a native SQL Server solution using T-SQL\xa0 code and a maintenance plan, it run min by min and send an email to DBA\xa0 team if it is not able to connect to any of the database in the instance. I do  ...

# %%
import pandas as pd
import re

# Define a function to clean the content
def clean_resume(content):
    # Find the position of the last occurrence of '</span>'
    last_span_index = content.rfind('</span>')
    if last_span_index != -1:
        # Remove everything before and including the last '</span>'
        content = content[last_span_index + len('</span>'):]
    # Replace all occurrences of '\xa0' with '\n'
    content = content.replace('\xa0', '\n')
    return content.strip()  # Remove any leading/trailing whitespace

# Apply the cleaning function to the 'content' column
df["resume_content"] = df["resume_content"].apply(clean_resume)

# %%
df["resume_content"][0]
df.to_csv("cleaned_resumes.csv", index=False, encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["resume_content"][0]
#       2 df.to_csv("cleaned_resumes.csv", index=False, encoding='latin-1')
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Data Preprocssing
#
# 1. randomly generate personal information including name, education, etc
# 2. break down the resume data into differen sections

# %%
import pandas as pd
import openai

openai.api_key = "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"

# %%
# Load your CSV file
df = pd.read_csv("cleaned_resumes.csv", encoding='latin-1')

# %%
# A list of top universities can be embedded in the prompt or provided as context.
# For simplicity, we can just instruct the model to pick from top universities 
# (the model knows many top universities: Harvard, Stanford, MIT, Oxford, Cambridge, etc.)
# If you want more control, you can embed a list of top universities in the prompt.

def generate_personal_info_only(resume_text):
    print(resume_text[:50])
    prompt = f"""
You are an assistant who is helping to add realistic personal details to a professional resume that currently lacks personal information. The resume content below describes a professional (e.g., a database administrator). You need to randomly generate:

1. A plausible full name, which can come from any race, ethnic group, or nationality. The name should be realistic and not identical to any real famous figure. For example, something like "Arjun Patel" or "Maria Nguyen" or "Kai Matsumoto".

2. A plausible educational background that matches the candidate's experience timeline and professional level. The background should make sense. For example, if the resume suggests about 5 years of working experience up until 2018 as a database administrator, the candidate likely completed their undergraduate degree at least 7-10 years prior (e.g., completed a Bachelor's degree around 2010-2012 if that fits). If they are highly experienced (10+ years), they might have completed education even earlier. The degree should align with their field (Computer Science, Information Technology, Software Engineering, etc.). Include:
   - The name of a top 200 globally ranked university (e.g., Stanford, MIT, Oxford, Cambridge, University of Toronto, ETH Zurich, National University of Singapore, etc.).
   - The degree (Bachelor's, Master's, or PhD) and the major.
   - Attendance years that align reasonably with their career timeline. For instance, if the resume indicates they've been working as a database admin since 2010, maybe they graduated with a Bachelor's around 2007-2009.
   - If they have extensive experience and advanced roles, consider they might have a Master's degree as well. But do not overcomplicate. If the candidate seems mid-level, a Bachelor's might suffice.

3. A realistic and professional-looking email address (e.g., Gmail, Outlook, or Yahoo), ensuring the email address is some randomly combinations of numbers and letters

4. A random city in the United States as their current location (e.g., Seattle, Chicago, Boston).

Make sure the personal info does not conflict with the resume content. Do not invent employers or personal addresses, just education background, email address and location.

Finally, output these personal details at the beginning, in a professional format, followed by a newline. 

Include a randomly generated full name. Do not include the resume content itself in your answer, only produce the personal details, formatted as follows: Name: [Full Name] Email: [Email Address] Location: [City, USA] Education: [Degree, Major, University, Attendance Years]

Use the resume text below as context.

Resume Content:
\"\"\"{resume_text}\"\"\"
"""

    # Call the OpenAI API
    response = openai.ChatCompletion.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.7,
        max_tokens=1000
    )

    return response.choices[0].message.content.strip()

def prepend_personal_info(row):
    personal_info = generate_personal_info_only(row['resume_content'])
    # Prepend the personal info to the resume content locally, without asking the API again
    return f"{personal_info}\n\n{row['resume_content']}"

# Generate the new column by applying the function
df['resume_personal'] = df.apply(prepend_personal_info, axis=1)

print(df['resume_personal'][:10])
# Out:
# Database Administrator - Family Private Care LLC L
# sql server database administrator Houston, TX DATA
# Oracle Database Administrator - Cognizant hyderaba
# and ETL Developer, Business Intelligence ETL Devel
# Scrum Master Scrum Master Scrum Master Richmond, V
# Oracle Database Administrator - SUNTRUST BANK Fort
# Oracle Database Administrator - Caresource Cincinn
# /Developer Lead Database Administrator/Developer -
# Developer Database Administrator / Database Develo
# Oracle Database Administrator - Uber Technologies
# Database Administrator - Booz Allen Hamilton Los A
# Senior Oracle Database Administrator - United Heal
# Database Administrator - First Tennessee Bank Work
# Database Administrator Redmond, WA Work Experience
# /SQL DBA SQL Database Administrator/SQL DBA A cert
# DBA DBA DBA  Over 6 (Six) years of professional e
# /Developer SQL Server Database Administrator/Devel
# SQL Server Database Administrator - FEDERAL RESERV
# SQL Developer / DBA SQL Developer / DBA SQL Develo
# Systems Administrator - Automann West New York, NJ
# Oracle Database Administrator - Sedgwick CMS Memph
# Oracle Database Administrator - Jelani Consulting
# CSR CSR Administrator  Network  System  Databas
# Oracle Database Administrator Fairfield, OH  Over
# (contractor) Database Administrator (contractor) -
# DBA/ Database Administrator - Bridge IT Support Se
# Oracle Database Administrator - Executive Office f
# Phoenix, AZ Authorized to work in the US for any e
# Volunteer Volunteer Atlanta, GA Experience with SQ
# Oracle Database Administrator - Delta Airlines * M
# Database Administrator - HPE/DXC/Perspecta Bloomfi
# Sr Enterprise Database Administrator Arlington, TX
# Oracle Database Administrator - Cotiviti White Pla
# SQL Database Administrator - Wing Zone Hyattsville
# PROJECT MANAGER PROJECT MANAGER PROJECT MANAGER -
# , Amdocs DVCI Database Administrator, Amdocs DVCI
# SQL Database Administrator - AGO GLOBAL CONSULTING
# Sr. Business Analyst Sr. Business Analyst Sr. Busi
# Oracle Database Administrator Woodbridge, VA I am
# Oracle Database Administrator Woodbridge, VA I am
# SQL Server Database Administrator - Comcast Cable
# Database Administrator - Service Source Inc Alexan
# SQL Server DBA SQL Server DBA SQL Server DBA - Aur
# Business Intelligence Database Administrator - Ame
# COOK COOK COOK - SOUTHERN HILLS COUNTRY CLUB Tulsa
# AND SYSADMIN CONSULTANT DATABASE AND SYSADMIN CONS
# Edison, NJ Work Experience Senior Database Adminis
# Oracle Database Administrator - Jelani Consulting
# SQL Server Database Administrator - PenFed Credit
# SQL Server Database Administrator - Pricewaterhous
# Sr.SQL Server Database Administrator - Cox Enterpr
# Security Engineer Sr. Oracle, PostgreSQL Database
# Data Engineer Data Engineer Data Engineer - United
# (Oracle) Database Administrator (Oracle) Madison,
# Software Developer Software Developer Software Dev
# Web Developer Web Developer Web Developer Work Exp
# Development Engineer Principal Database Developmen
# Business Analyst Business Analyst Information Tech
# SQL Database Administrator - SouthCoast Health Sav
# Application, Database & Security Administrator - O
# SQL Database Administrator - MetLife Queens, NY Ce
# Scrum Master Scrum Master Scrum Master - Connectio
# Oracle Database Administrator - FedEx Supply Chain
# DEVOPS DBA DEVOPS DBA Charlotte, NC Looking for ne
# Senior Technical Engineer Lehi, UT Over 8 years of
# Database Administrator - Posh Lane Freight Smyrna,
# Specialist/DBA SQL Server Database Specialist/DBA
# Cyber Security Analyst/RMF Specialist (Veteran Aff
# Picayune, MS Authorized to work in the US for any
# Architect Database Architect Hillsboro, OR Informa
# Oracle Database Administrator - Business Solutions
# Hartford, CT  Full responsibility and expertise i
# Application Database Administrator - INFOSYS LTD R
# Scrum Master Scrum Master Scrum Master - U.S Bank
# Duarte, CA I'm pursuing an investment specialist.
# Manager Donor and Data Management Manager Donor an
# Scrum Master Scrum Master Scrum Master - Salazar I
# DBA/Admin SQL Server Database DBA/Admin - OPTUM Ca
# /DBA) Sr.MongoDB Architect (Developer/ Administrat
# Database Administrator - CCA Global Partners St. L
# Financial Analyst Financial Analyst Niantic, CT Wo
# Database Administrator Lone Jack, MO Talented Data
# POS Database Administrator - Xenial, Inc Warminste
# Database Administrator - IBM consulting Boston, MA
# Scrum Master/Report Analyst Scrum Master/Report An
# BUSINESS MANAGER/PURCHASING COORDINATOR BUSINESS M
# Data Warehouse Eng Data Warehouse Eng Data Warehou
# Senior Oracle Database Administrator - Thomson Reu
# Help Desk Manager Help Desk Manager Help Desk Mana
# Database Administrator Washington, DC Work Experie
# A recognized leader A recognized leader A recogniz
# /Data Analyst Sr. Database Administrator/Data Anal
# Lead Oracle DBA Lead Oracle DBA Lead Oracle DBA Wa
# Database Administrator - Ultrafryer Schertz, TX Ex
# SQL/ETL Developer SQL/ETL Developer SQL/ETL Develo
# Oracle Database Administrator - SUBARU AUTOMOTIVE
# Network and Database Administrator - Lipsey Logist
# RESEARCH DATABASE ADMINISTRATOR - THE ALEXANDER GR
# Scrum Master Scrum Master Scrum Master - AKS Cyber
# Help Desk Technician Help Desk Technician Database
# F-35 Suitability Analyst F-35 Suitability Analyst
# (SQL) Database Administrator (SQL) Middle River, M
# DBA DBA DBA - Omnitracs Worcester, MA 7+ Years of
# Customer Quality Specialist Customer Quality Speci
# /Snr System Analyst Oracle Database Administrator/
# Manager Database Manager Miramar, FL oriented, sel
# Warehouse Specialist Warehouse Specialist Spruce P
# Operations Manager Operations Manager Saint Paul,
# I Database Administrator I - C Spire Work Experien
# Oracle Database Administrator - General Motors Can
# Actimize Analyst Actimize Analyst Fairfax, VA ? Ov
# Medical Lab Technician Medical Lab Technician Medi
# Database Administrator - Chesapeake Bay Program Of
# Oracle Database Administrator - Icreon Hyattsville
# Lead Analyst/Product Owner Lead Analyst/Product Ow
# Corporate Buying Data Assistant Corporate Buying D
# Creator/Developer Creator/Developer UX Research an
# III SharePoint/DBA/Analyst Norfolk, VA I am a rela
# Escondido - Volunteer Massage (Therapy) Escondido
# Database Administrator - Roots Data Systems Silver
# Oracle Database Administrator - Aramark Refreshmen
# Data Engineer Data Engineer Graduate Student at Un
# Health Care Data Analyst Health Care Data Analyst
# Oracle Database Administrator Bowie, MD Authorized
# Oracle Database Administrator - Holy Cross Hospita
# Data & Ecommerce Analyst Data &amp; Ecommerce Anal
# Technical Representative Technical Representative
# HealthShare Developer HealthShare Developer Health
# Database Administrator - Verizon Wireless Rivervie
# SQL SERVER DBA SQL SERVER DBA M&T BANK SQL SERVER
# Oracle Database Administrator Houston, TX Database
# Systems Engineer/ Database Administrator Chicago,
# Job Seeker  Having 2+ years of experience in Orac
# Project Leader, Erbil, Iraq Project Leader, Erbil,
# Business Intelligence Analyst Intern Business Inte
# DATABASE ADMINISTRATOR - Nalley Atlanta, GA Detail
# Data Analyst Data Analyst Research Assistant - Ste
# Oracle Database Administrator - Remote Database Ex
# Scrum Master Scrum Master Scrum Master - Dell Inc
# Security Operation Center (SOC) Analyst Security O
# (Current) Database Administrator Los Angeles, CA A
# , Human Reasources Office Administrator, Human Rea
# I.T. Support Technician I.T. Support Technician I.
# ServiceNow Trainee Analyst ServiceNow Trainee Anal
# Sourcing Specialist, Power Sourcing Specialist, Po
# /Maintenance Manager Database Administrator/Mainte
# SQL Server Database Administrator - Next Media Inc
# Junior Database Administrator Elma, NY Work Experi
# /Legal Secretary Database Administrator Houston, T
# Technical Support Representative Technical Support
# Background Verification Specialist Background Veri
# Lab Support Lab Support IT Professional Cary, NC A
# BI Developer BI Developer San Francisco (Bay area)
# Business Analyst Business Analyst Monterey Park, C
# SQL Server Database Administrator - Universal Herb
# Programmer/CNC Programmer/CNC IT Specialist and En
# Data Processing Caging Support Specialist Data Pro
# / Consultant Oracle Database Administrator/ Consul
# MS SQL Server Database Administrator Fair Oaks, CA
# Account Manager Account Manager Account Manager -
# Intern Database Administrator Intern - Protech Sol
# Data/ QA Analyst Data/ QA Analyst Data/ QA Analyst
# Consultant Consultant Consultant - Enterprise Reso
# Used Truck Sales Used Truck Sales Used Truck Sales
# Data Analyst Data Analyst Atlanta, GA Authorized t
# Database and Application Administrator - ACCENTURE
# (SQL), and Web Developer/GIS Administrator(s), Com
# Database Administrator - Surescripts Minneapolis,
# Database Administrator ? A dependable and diligent
# Project Manager Project Manager Houston, TX Author
# Network Security and Database Administrator - Lips
# Programmer Analyst Programmer Analyst Programmer A
# /Engineer Senior SQL Server DBA/Engineer East Brun
# I/ Sysadmin Administrator I - Brentwood Services A
# Newport News, VA Work Experience Database Administ
# Lead DATABASE LEAD - Archer Daniel Midland (ADM) E
# Production Leader Production Leader Production Lea
# Birmingham, AL Authorized to work in the US for an
# Database Administrator - United States Navy Virgin
# Oracle Database Administrator 3+ years of experien
# Aircraft Mechanic/ Database Administrator - US Arm
# (Consultant) Database Administrator (Consultant) -
# Remote Hands Technician Remote Hands Technician Re
# SQL Server Database Administrator Lawrenceville, G
# Sr. BusinessAnalyst Sr. BusinessAnalyst Sr. Busine
# Oracle Database Administrator - Pritchard & Jerden
# Sr. Database Administrator - GSS InfoTech ? Over F
# Architect/Admin, Cassandra admin, MS SQL Admin, Co
# APPLICATION DEVELOPER APPLICATION DEVELOPER Charlo
# Business Analyst for People Analytics Business Ana
# (Team Lead) Database Administrator (Team Lead) Sac
# (DBA) Microsoft SQL Server Database Administrator
# Production SQL Server Database Administrator - Mod
# Sr. Business Analyst Sr. Business Analyst Sr. Busi
# SQL Server Database Administrator - Mahamittra Gro
# Sr. Database Administrator - Prime Therapeutics Me
# Engineer Oracle Database Engineer - KeyBank Montan
# Sr IT Consultant contractor Sr IT Consultant contr
# SCRUM MASTER SCRUM MASTER SCRUM MASTER(SSM) Charlo
# Business Intelligence Developer Business Intellige
# Sr. SQL Server DBA Sr. SQL Server DBA Sr. SQL Serv
# Database Administrator - Cybernet LLC & Caspian De
# IT Jack of all trades - If I don't know it I learn
# Scrum Master Scrum Master Scrum Master - Veeam Sof
# Sr. Oracle DBA Sr. Oracle DBA Sr. Oracle DBA - Car
# Sr. Oracle Database Administrator - Harvard Piligr
# Sr. Oracle DBA Consultant Sr. Oracle DBA Consultan
# Oracle/SQL Database Administrator - PeopleSoft Fin
# Linux Administrator - Con-way Silver Spring, MD Wo
# IT SPECIALIST II IT SPECIALIST II IT SPECIALIST II
# Insight Global - Business System Analyst contracte
# Web Developer Oakland, CA Certificate in Full Stac
# Oracle Database Administrator Work Experience Orac
# Database Administrator Reading, PA Work Experience
# Oracle Database Administrator - VERIZON Silver Spr
# Technical Expert Data Analytics Mentor Technical E
# Database Administrator Work Experience Database Ad
# Auburn, GA I am seeking a position as a SQL Server
# Oracle Database Administrator Lanham, MD Authorize
# DBA DBA Database Administrator Oklahoma City, OK L
# DB2 DBA & Developer DB2 DBA &amp; Developer DB2 DB
# Oracle Database Administrator - Verizon Wireless D
# Lenexa, KS Work Experience Oracle Database Adminis
# SQL Database Administrator Fort Worth, TX Work Exp
# Software Engineer/ Database Administrator - S&K Lo
# /Applications DBA/Scrum Master Oracle Database Adm
# Specialist SQL Server Database Specialist - NBTY,
# Pilot in training Pilot in training Database Admin
# Sr. Oracle Database Administrator - Trade Navigato
# Oracle Database Administrator - NFP  Experience i
# Marketing Business Analytics Specialist, Officer M
# Sr. SQL Database Administrator - Pentagon Federal
# Oracle Database Administrator - Zimmer Biomet Inc
# Junior Oracle Database Administrator Valley Stream
# IT Security Analyst IT Security Analyst IT Securit
# Lead IT Security Compliance Analyst Lead IT Securi
# Oracle Database Administrator - US COAST GUARD Che
# Oracle Database Administrator - Verizon Wireless D
# Database/Systems Administrator Las Vegas, NV Aviat
# Junior AWS Cloud Solutions Architect Junior AWS Cl
# I Panama City, FL Authorized to work in the US for
# SQL Server Database Administrator Houston, TX An E
# Oracle DBA Oracle DBA Oracle DBA - Heron Solutions
# ORACLE DATABASE ADMINISTRATOR - Oracle Corporation
# Systems Administrator - Star Gas Partners Selden,
# SQL Server DBA SQL Server DBA SQL Server DBA - Ind
# AWS Architect AWS Architect AWS Architect - Deloit
# Sr. SQL Server DBA Sr. SQL Server DBA Sr. SQL Serv
# - DBA SQL Database Administrator - DBA - MIMAKI US
# IT Manager / Programmer IT Manager / Programmer IT
# Database Administrator - TATA Consultancy Services
# IT User Support Supervisor IT User Support Supervi
# Scrum Master Scrum Master Scrum Master Houston, TX
# SQL Server Database Administrator - AAA Carolinas
# BI/ SSRS Developer BI/ SSRS Developer BI/ SSRS Dev
# Jr. Database Administrator - NEW DIRECTIONS BEHAVI
# Sr. Oracle Database Administrator East Windsor, CT
# Oracle Database Administrator Houston, TX Highly t
# Database Administrator Alexandria, VA * Extensive
# Database administrator - Adilas Tech LLC Woodbridg
# SQL Server Database Administrator - California Sta
# Document Management Professional (15 years) (REMOT
# QA Engineer QA Engineer Software QA Engineer Saint
# Oracle Database Administrator Dallas-Fort Worth, T
# Security Controls Assessor Security Controls Asses
# Data Analyst Data Analyst Data Analyst Carrollton,
# Oracle Database Administrator - Iowa Foundation fo
# Program Director Program Director Work Experience
# Cloud Architect Cloud Architect Cloud Architect -
# Oracle Database Administrator - HCA HEALTH  Oracl
# SharePoint Developer SharePoint Developer SharePoi
# Nashville, TN ~7 years of IT experience, including
# Oracle Database Administrator - Zimmer Biomet Inc
# Scrum Master Scrum Master Scrum Master - AT&T Land
# Database Administrator - Adilas Tech Dallas, TX ?
# ASSISTANT ADMINISTRATIVE ASSISTANT Garden Grove, C
# Oracle Database Administrator  More than 5 years
# Oracle Database Administrator Springfield, VA  Pr
# SQL Server DBA and ETL Developer SQL Server DBA an
# SENIOR ORACLE DATABASE ADMINISTRATOR Tennessee, IL
# Oracle Database Administrator Bowie, MD I am OCA 1
# IT Healthcare Consultant/SIS Database Administrato
# Derivatives (HFT) Sales Broker Derivatives (HFT) S
# Systems Administrator Tampa, FL System Administrat
# Cyber Security Analyst Cyber Security Analyst IT O
# COMMISSIONED SECURITY OFFICER COMMISSIONED SECURIT
# Consultant/ Business Analyst Chicago, IL  Highly
# Sr. Oracle Database Administrator - Portland Gener
# Oracle Database Administrator Pittsburgh, PA Autho
# Sr. Database Administrator - PBGC Kansas City, KS
# - Linux Oracle Database Administrator - Linux - Li
# Oracle Database Administrator - General Motors Rou
# &amp; Academic Support Specialist -Talent Gateway
# Database Administrator Work Experience Database Ad
# Oracle Database Administrator - LUXOTTICA Hyattsvi
# Database Administrator - Wheeling Jesuit Universit
# Salt Lake City, UT Authorized to work in the US fo
# Database Administrator Fairfax Over 5 years of exp
# ORACLE DATABASE ADMINISTRATOR - Citizens Bank, Rho
# Reports Developer Reports Developer Consulting San
# Pricing & Data Analytics Professional Arlington, V
# Engineer SQL Database Engineer Prospect, CT Work E
# Consultant - Technical Implementation Specialist (
# Oracle Database Administrator - Priority One Servi
# Oracle Database Administrator - Priority One Servi
# Cherwell Administrator - Dell Technologies Inc Rou
# Consultant Capgemini Consulting Technology Outsour
# Engineer Chief Projects Coordinator - Baltimore Bl
# Sr. Oracle DBA/GoldenGate SME Sr. Oracle DBA/Golde
# DevOps Cloud Architect DevOps Cloud Architect DevO
# Job Seeker Talented with more than 2 years' experi
# Medical Leave of Absence Medical Leave of Absence
# AWS Cloud Engineer AWS Cloud Engineer AWS Cloud En
# /Developer DevOps Developer for the Database Admin
# Broken Arrow, OK I have several years of IT experi
# Office Manager, Indiana Office Manager, Indiana Of
# Splunk Engineer Splunk Engineer Splunk Engineer -
# II SQL Database Administrator Tamarac, FL Authoriz
# AWS Solution Architect/DevOps Engineer AWS Solutio
# Sr. SharePoint Developer Sr. SharePoint Developer
# Acton, MA Sponsorship required to work in the US W
# Oracle Database Administrator Baltimore, MD Over 4
# CLUB COORDINATOR/EVENT COORDINATOR CLUB COORDINATO
# Developer Silver Spring, MD I have 10 years experi
# Team Coordinator Team Coordinator Team Coordinator
# Actimize Analyst Actimize Analyst Actimize Analyst
# Developer and Database Administrator - AutoMatStor
# Young Marines National Headquarters Database Admin
# Case Manager Case Manager Case Manager/Legal Assis
# SQL DBA SQL DBA SQL DBA - SalientCRGT, Inc Woodbri
# Security Analyst Intern Security Analyst Intern Se
# Cloud Network Engineer Cloud Network Engineer Clou
# Oracle Database Administrator - TeyeMatics Inc Ros
# Oracle DBA Oracle DBA Oracle DBA - RMA Bowie, MD T
# AML Model and Analytics AML Model and Analytics Da
# /Developer, Business Operations Senior Database Ad
# FREELANCE FREELANCE FREELANCE - Email Marketing Ca
# Full Stack Developer/IT Full Stack Developer/IT Fu
# Systems Engineer - Systems Administrator - R-Assoc
# Project Coordinator Project Coordinator Project Co
# Paralegal Paralegal Paralegal Dallas, TX Paralegal
# Consultant Database Consultant - Project Sunshine
# Marketing Manager Marketing Manager Marketing Mana
# Research Technician Research Technician Research T
# Oracle Database Administrator - K & K Consulting G
# Network Administrator Raleigh, NC To use my combin
# Project Manager/ Database Administrator - Sanray C
# Admin/DBA/Analyst SQL Server Database Admin/DBA/An
# Oracle Database Administrator - Apex Group Over 8+
# Help Desk Administrator Sunrise, FL To obtain a po
# and Developer Database Administrator and Developer
# Oracle Database Administrator - Delta Air Lines Ea
# SQL Server DBA SQL Server DBA SQL Server DBA - Wel
# (DBA) SQL Server Database Administrator (DBA) - WO
# Tactical Power Generation Specialist Tactical Powe
# Oracle Database Administrator - disys solution inc
# Cloud Operations Engineer Intern Cloud Operations
# City Planner II & Development Review Administrator
# Innovation Account Manager Innovation Account Mana
# SQL Server Database Administrator - IBM India Pvt.
# System Administrator - Cedars-Sinai Hospital Los A
# Scrum Master Scrum Master Scrum Master - DXC New O
# Database Administrator - Posh Lane Freight Smyrna,
# Oracle Database Administrator - Cardinal Health La
# Health Care Data Analyst Health Care Data Analyst
# Patient Care Technician Patient Care Technician Pa
# Database Administrator Silver Spring, MD ? 6+ year
# Licensed Relationship Banker Licensed Relationship
# Stoutsville, OH Hard-working GIS professional skil
# IT field Technician IT field Technician IT field T
# SQL DBA SQL DBA Atlanta, GA Work Experience SQL DB
# Certified Scrum Master/Business Analyst Certified
# SQL Server DBA SQL Server DBA SQL Server DBA - NYC
# Peoplesoft Database Administrator - Towson Univers
# External Fraud Investigator - U.S. Bank Columbus,
# SCRUM MASTER( AGILE) SCRUM MASTER( AGILE) SCRUM MA
# Photographer/Film Editor Photographer/Film Editor
# Database Administrator CSC Bowie, MD Work Experien
# Admin support SQL Developer / Database Admin suppo
# /Developer Sr. Database Administrator/Developer Re
# BUSINESS MANAGER/PURCHASING COORDINATOR BUSINESS M
# Diplomatic Security Officer/Console Operator Diplo
# Sr. Oracle Database Administrator - Centene Corpor
# Programmer Analyst Information Technology Database
# Sales/Merchandising Assistant Sales/Merchandising
# SQL DATABASE ADMINISTRATOR Gettysburg, PA Database
# SQL Server Database Administrator - Strategic Inte
# Oracle Database Administrator - PEPCO HOLDINGS Hya
# SENIOR ANALYST - CLINICAL OPERATIONS SENIOR ANALYS
# Associate Database Administrator - Vanderbilt Univ
# Sr. Oracle and SQL Server DBA Sr. Oracle and SQL S
# Systems and DevOps Administrator - Full Stack Deve
# /Analyst Database Administrator/Analyst - Berkley
# Oracle Database & Banner (ERP) Administrator - HAR
# Executive Database Administrator New York, NY Work
# Data Developer/Power BI Admin Data Developer/Power
# Oracle Database Administrator Hyattsville, MD Orac
# Rural Carrier Associate Rural Carrier Associate Ma
# Computer vision project assistant Computer vision
# Quality Assurance Inspector Quality Assurance Insp
# IT Manager IT Manager IT Manager Concord, CA Exten
# and Solutions Architect Oracle Database Administra
# Freelance/Consulting - Greater Freelance/Consultin
# Psychologist - Psychotherapist Psychologist - Psyc
# Analyst Database Analyst - Wells Fargo Charlotte,
# Aviation Maintenance Program Coordinator Aviation
# Senior Oracle Database Administrator - Global Heal
# Laurel, MD To apply my education and experience to
# Sr. Oracle Database Administrator - The Northern T
# Applications Programmer Analyst Applications Progr
# Associate Manager Associate Manager Associate Mana
# Cyber Security Analyst Cyber Security Analyst Cybe
# Remote DBA Remote DBA Remote DBA - Computer Scienc
# IT Infrastructure Manager IT Infrastructure Manage
# Manager A skilled IT professional with 9 years of
# Security Analyst Security Analyst Laurel, MD Autho
# Director of Project Management & Market Research D
# Developer/Analyst Database Developer/Analyst - BCB
# Oracle DBA Bowie, MD Daniel is a highly skilled pr
# Database Administrator - Maxim Healthcare Services
# Senior IOS Developer Senior IOS Developer Senior I
# for 24/7 support Primary DBA for 1GB - 2.5TB datab
# Software Developer Software Developer Carrollton,
# Sr Sap Basis/ HEC consultant Sr Sap Basis/ HEC con
# Project Manager Project Manager Project Manager Ch
# Oracle Database Administrator - SUNTRUST BANK Arli
# Oracle Database Administrator - Long Island Univer
# MongoDB Developer MongoDB Developer MongoDB Develo
# Agile Scrum Master Agile Scrum Master Agile Scrum
# Oracle Database Administrator - Arafat Travel Arli
# Director of Payroll Operations Director of Payroll
# Data Visualization Analyst Data Visualization Anal
# Specialist II Database Specialist Ellwood City, PA
# Support Computer Systems Analyst/Programmer - Data
# &amp; Staff Accountant Leasing Administrator & Sta
# Sr. Oracle Database Administrator/AWS Cloud Admini
# Admin gudang Admin gudang denpasar Work Experience
# Sr.Net Software Engineer Sr.Net Software Engineer
# Colorado Springs, CO Work Experience Database Admi
# Oracle DBA/Developer Oracle DBA/Developer Oracle D
# Oracle Apps Database Administrator Los Angeles, CA
# Application Database Administrator Atlanta, GA Aro
# ServiceNow Developer ServiceNow Developer ServiceN
# Database Administrator - ISKCON of Alachua Alachua
# MS SQL Database Administrator - KiawiTechIT Consul
# Sr. Business Analyst Sr. Business Analyst Sr. Busi
# Public Records Researcher Public Records Researche
# Mendenhall, MS Seeking a challenging position that
# Oracle Database Administrator Edwardsville, IL Com
# Data Analyst Data Analyst Data Analyst - CCHC Inc
# Pricing Operation's Database Administrator - Eaton
# Client Success Team Member-National Debt Relief Al
# Application Database Administrator - K.K IMPEX Com
# Package Handler Package Handler Package Handler -
# Database Administrator - New Jersey Sharing Networ
# Sr. Oracle DBA Sr. Oracle DBA Sr. Oracle DBA - CIT
# IT Analyst IT Analyst IT Support Technician Fitchb
# Sr. Database Administrator - Midfirst Bank Edmond,
# Medical Assistant/Front Desk Medical Assistant/Fro
# Audio Engineer Audio Engineer Roseville, CA Highly
# Bilingual Receptionist Bilingual Receptionist Fair
# /Analyst Database Administrator/Analyst - Berkley
# , BIM Director, Sysadmin Database Administrator, B
# Database Analyst - Fit-Wel Custom Clothes, LA, CA
# Materials Planner Materials Planner Materials Plan
# Program Analyst Program Analyst Denver, CO Authori
# MS SQL Server DBA MS SQL Server DBA MS SQL Server
# AIRCRAFT LOAD PLANNER AIRCRAFT LOAD PLANNER AIRCRA
# II Raleigh, NC Results-oriented Certified MySQL DB
# SQL BI Developer/SSIS/SSRS/SSAS SQL BI Developer/S
# Tech Support Tech Support Tech Support Festus, MO
# SQL BI Developer/SSIS/SSRS/SSAS SQL BI Developer/S
# Support Engineer Support Engineer System Analyst/E
# Database administrator Germantown, MD Database Adm
# Database Administrator - Adalante Healthcare Glend
# Director Fraud and Database Specialist Los Angeles
# SQL Developer Jonesboro, AR Authorized to work in
# Sr SQL Server Database Developer/ Administrator -
# Database Administrator/Developer Falls Church, VA
# Account Services Assistant Account Services Assist
# IT Administrator/Data Entry Specialist, Database A
# Customer Support Supervisor Customer Support Super
# Business Analyst Business Analyst Business Analyst
# Linux System Administrator - Multimedia Genius, In
# Consultant - Supply Chain Management Consultant -
# Huntsville, AL Authorized to work in the US for an
# Project 90 - Office Administrator - Caminar Haywar
# Sr. Mongos DB/Oracle DBA Sr. Mongos DB/Oracle DBA
# Oracle Database Administrator - TCS  Over 6 years
# ADMINISTRATIVE SUPPORT SPECIALIST (MARKETING & TRA
# CONSULTANT CONSULTANT Pittsburgh, PA Authorized to
# IT Specialist IT Specialist Margate, FL I am an an
# Purchasing Coordinator / Project Coordinator Winte
# (DBA) SQL Server Database Administrator (DBA) - De
# Strategic and Technical Sales Consultant Strategic
# Project Management Quality Specialist Project Mana
# SQL Database Administrator - TRW /ZF Highly motiva
# Sr. DevOps/Cloud Engineer Sr. DevOps/Cloud Enginee
# Business Services Representative - Receptionist (W
# Worship Director Worship Director Crown Point, IN
# Specialist Youth Ministry Administrator, Small Gro
# Sr. Oracle DBA Sr. Oracle DBA Sr. Oracle DBA - Uni
# Sr. Oracle DBA Sr. Oracle DBA Sr. Oracle DBA - Mer
# Student Student Family Caregiver Washington, DC DA
# GM Motors GM Motors GM Motors - Raytheon Remote Wo
# BI Enterprise Data Warehouse Architect BI Enterpri
# DATABASE ADMINISTRATOR - NYC DEPARTMENT OF HPD Edi
# Oracle Database Administrator - Hogan Transport Ll
# Reservations & Office Manager - National Ability C
# Oracle DBA Oracle DBA Oracle DBA - Tango Analytics
# Assistant for Word Alive Administrative and Databa
# SQL Server DBA SQL Server DBA SQL Server DBA - VER
# Environmental Protection Specialist Environmental
# Sales Associate Sales Associate Sales Associate Po
# Bank Teller Bank Teller Bank Teller - Wells Fargo
# Sr. Administrative Assistant Sr. Administrative As
# Buffalo, NY Technologically-minded professional an
# MSSQL DATABASE ADMINISTRATOR - JOHNS HOPKINS UNIVE
# Analyst Junior Oracle Database Administrator Houst
# II Communications Manager Olathe, KS Highly skille
# Fremont, CA High?performing, strategic?thinking pr
# Web Developer/IT Support Web Developer/IT Support
# IT Applications Analyst IT Applications Analyst IT
# and Oracle DBA Sr. PeopleSoft System Administrator
# Database Administrator - Qualcomm India Private Li
# Scrum Master Scrum Master Scrum Master Washington,
# Technical Business Analyst Technical Business Anal
# SQL Server DBA SQL Server DBA SQL Server DBA - Wel
# IT SECURITY ANALYST IT SECURITY ANALYST IT SECURIT
# Developer Database Developer - VariQ Corporation E
# Portfolio Accountant Portfolio Accountant Portfoli
# Executive Assistant & Database/Market Administrato
# NttData-customer service rep NttData-customer serv
# AWS Engineer AWS Engineer AWS Engineer - Allianz L
# Sortation Associate Sortation Associate MSSQL DBA
# Application Support Specialist Application Support
# Summer Missionary Summer Missionary Customer Servi
# Network Engineer / Programmer Network Engineer / P
# CRM Analyst (Contract) CRM Analyst (Contract) Pitt
# Senior Oracle DBA Senior Oracle DBA Senior Oracle
# Database Architect / Snr. Database Administrator -
# / Project Manager Passionate Salesforce Administra
# Sr.SQL Server DBA Sr.SQL Server DBA Sr.SQL Server
# BUSINESS SYSTEMS ANALYST BUSINESS SYSTEMS ANALYST
# Office Assistant Office Assistant Office Assistant
# 8+ Years of IT Experience as an Oracle Database Ad
# AWRDS Manager AWRDS Manager AWRDS Manager - CGI Fe
# VP SQL Developer VP SQL Developer VP SQL Developer
# MS SQL Server DBA MS SQL Server DBA MS SQL Server
# Nodal Network Systems Operator-Maintainer Instruct
# Junior Front-end developer Junior Front-end develo
# Database Administrator - Provalus Opp, AL Work Exp
# Beaumont, TX Authorized to work in the US for any
# Job Seeker Work Experience EXTREME FITNESS - Litho
# Project Manager Project Manager Project Manager -
# TRV Specialist TRV Specialist IT Professional Wich
# IT Field Technician IT Field Technician Engineerin
# Security Analyst Security Analyst Security Analyst
# /SharePoint Developer SharePoint Administrator/Sha
# DATABASE MASTER ADMINISTRATOR - ABUNDANT LIFE CHRI
# Field Service Engineer Field Service Engineer Fiel
# Coordinator Certified Salesforce Administrator Dur
# SQL SEVER Database administrator - EHP VENTURE, VA
# Database Administrator and Administrative Assistan
# SQL Server Database Administrator - Aspiraconnect
# Digital/Ecommerce Coordinator Technician Digital/E
# Wireless Manager Wireless Manager Odenton, MD Work
# Quality Assurance Auditor Quality Assurance Audito
# Business Analyst/ Scrum Master Business Analyst/ S
# Curriculum Development Specialist Curriculum Devel
# Data Analyst Data Analyst Dallas, TX Work Experien
# Account Management Specialist Account Management S
# PROJECT MANAGER/TECHNICAL SUPPORT OFFICER PROJECT
#  Subcontractor GDIT (USDOJ/OCIO) Database Adminis
# Data-Driven Administrator Springfield, VA Unique a
# / Administrative Contractor Administrative Assista
# Program Director - grant writer Program Director -
# QUALITY & LOGISTICS MANAGER QUALITY &amp; LOGISTIC
# Administrative Coordinator Administrative Coordina
# Principal Data Architect Principal Data Architect
# Noida as Sr. Database Administrator - Droom Techno
# Application Developer Application Developer Applic
# SQL Server Database Administrator - American Incom
# Vice President Vice President Nashville, TN Experi
# Oracle Apps DBA Oracle Apps DBA Oracle Apps DBA -
# Database Administrator Alexandria, VA An able, ent
# HR Assistant / Database Administrator Sunny Isles
# Software Engineering - QA Analyst Software Enginee
# Special Education Aide Special Education Aide Colu
# Data Analyst Data Analyst Data Analyst Seattle, WA
# Membership Intake Program Specialist Membership In
# Program Assistant/ Front desk Associate Program As
# Oracle Database Administrator - US Steel Baltimore
# System Administrator - Direct of Information Techn
# Lead Application Analyst and Administrator - Globa
# Consultant Consultant Consultant - Infosys Technol
# /Developer Database Administrator / Business Intel
# Yoga Instructor Yoga Instructor Foreign Teacher As
# Administrator; Developer; System Analyst Database
# Cyber Privacy and Security Analyst Cyber Privacy a
# 0    Name: Priya Desai  \nEmail: priya.desai1990@gm...
# 1    Name: Amina Chen  \nEmail: amina.chen1985@gmai...
# 2    Name: Amir Khan  \nEmail: amirk1234@gmail.com ...
# 3    Name: Daniel Kim  \nEmail: daniel.kim1985@gmai...
# 4    Name: Amina Khan  \nEmail: ak12345@gmail.com  ...
# 5    Name: Maya Chen  \nEmail: mayachen1985@gmail.c...
# 6    Name: Samuel Kim  \nEmail: samuel.kim1987@gmai...
# 7    Name: Samuel Kim  \nEmail: samuel.kim1985@gmai...
# 8    Name: Elena Rodriguez  \nEmail: elena.rodrigue...
# 9    Name: Aria Chen  \nEmail: aria.chen1987@gmail....
# Name: resume_personal, dtype: object

# %%
df
# Out:
#       id                                     resume_content  \
# 0      1  Database Administrator - Family Private Care L...
# 1      2  sql server database administrator Houston, TX ...
# 2      3  Oracle Database Administrator - Cognizant hyde...
# 3      4  and ETL Developer, Business Intelligence ETL D...
# 4      5  Scrum Master Scrum Master Scrum Master Richmon...
# ..   ...                                                ...
# 595  596  Consultant Consultant Consultant - Infosys Tec...
# 596  597  /Developer Database Administrator / Business I...
# 597  598  Yoga Instructor Yoga Instructor Foreign Teache...
# 598  599  Administrator; Developer; System Analyst Datab...
# 599  600  Cyber Privacy and Security Analyst Cyber Priva...
#
#                                        resume_personal
# 0    Name: Priya Desai  \nEmail: priya.desai1990@gm...
# 1    Name: Amina Chen  \nEmail: amina.chen1985@gmai...
# 2    Name: Amir Khan  \nEmail: amirk1234@gmail.com ...
# 3    Name: Daniel Kim  \nEmail: daniel.kim1985@gmai...
# 4    Name: Amina Khan  \nEmail: ak12345@gmail.com  ...
# ..                                                 ...
# 595  Name: Priya Desai  \nEmail: priya.desai1985@gm...
# 596  Name: Amina Torres  \nEmail: amina.torres1987@...
# 597  Name: Mia Chen  \nEmail: miachen1987@gmail.com...
# 598  Name: David Kim  \nEmail: dkim1987@gmail.com  ...
# 599  Name: Elena Wu  \nEmail: elenawu1987@gmail.com...
#
# [600 rows x 3 columns]

# %%
import pandas as pd

# Concatenate 'resume_personal' to the beginning of 'resume_content'
df['resume_combined'] = df['resume_personal'] + "\n\n" + df['resume_content']

# Save the updated DataFrame to a new CSV file
df.to_csv('updated_resumes_combined.csv', index=False)

print("New column 'resume_combined' has been added and saved to 'updated_resumes_combined.csv'.")
# Out:
# New column 'resume_combined' has been added and saved to 'updated_resumes_combined.csv'.

# %% [markdown]
# ### Process the job description
#
# collected 558 job descriptions from data analyst, software engineer, data scientist, machine learning engineer and data engineer.

# %%
import pandas as pd
import os

# List of input CSV files
file_list = ['jobs_da.csv', 'jobs_de.csv', 'jobs_ds.csv', 'jobs_mle.csv', 'jobs_sde.csv']

# Initialize an empty list to store the "description" column from each file
descriptions = []

# Loop through each file and extract the "description" column
for file in file_list:
    # Load the CSV file
    df = pd.read_csv(file)
    # Extract the "description" column and add it to the list
    if 'description' in df.columns:
        descriptions.extend(df['description'].tolist())

# Create a new DataFrame with the collected descriptions
output_df = pd.DataFrame({'description': descriptions})
# Out:
# The descriptions have been extracted and saved to 'jd_description.csv'.

# %%
# Save the descriptions to a new CSV file
output_file = 'jd_description.csv'
output_df.to_csv(output_file, index=False)

print(f"The descriptions have been extracted and saved to '{output_file}'.")
# Out:
# The descriptions have been extracted and saved to 'jd_description.csv'.

# %% [markdown]
# ### Extract job details for Resume generating

# %%
import os
import openai
import pandas as pd
import json

# Set your OpenAI API key

# Your prompt template
JOB_DETAILS_EXTRACTOR = """ 
<task>
Identify the key details from a job description and company overview to create a structured JSON output. Focus on extracting the most crucial and concise information that would be most relevant for tailoring a resume to this specific job.
</task>

<job_description>
{job_description}
</job_description>

Note: The "keywords", "job_duties_and_responsibilities", and "required_qualifications" sections are particularly important for resume tailoring. Ensure these are as comprehensive and accurate as possible.  
"""

# Read your CSV file (assumes 'job_description' column)
df = pd.read_csv("jd_description.csv")

# %%
execution_count = 0
# Function to call the API for a single job description
def extract_job_details(description):
    global execution_count
    execution_count += 1
    print(f"Processing job description {execution_count}...")
    # Format the prompt with the job description
    prompt = JOB_DETAILS_EXTRACTOR.format(job_description=description)
    
    # Call the OpenAI API (using GPT-4 or the "gpt-4" model)
    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=1500,
        temperature=0
    )
    
    # The response content should be the JSON output
    # If the model just returns text, you may need to parse it as JSON.
    # Here, we assume the model returns valid JSON.
    content = response.choices[0].message["content"]
    
    # Optionally, you can try to parse the output as JSON. If it fails,
    # just store the raw text. Adjust error handling as needed.
    try:
        extracted_data = json.loads(content)
    except json.JSONDecodeError:
        # If JSON parsing fails, store the raw text.
        extracted_data = content
    
    return extracted_data

# Apply the extraction to each row in the DataFrame
df["extracted_job_details"] = df["description"].apply(extract_job_details)

# Write the updated DataFrame to a new CSV
#df.to_csv("output_jobs_with_details.csv", index=False)
# Out:
# C:\Users\MingyangWang\AppData\Local\Temp\ipykernel_27720\691714583.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["extracted_job_details"] = new_df["description"].apply(extract_job_details)

# %% [markdown]
# ### Merge the job description into one

# %%
import pandas as pd
import glob
import os

# Path where your CSV files are stored
csv_directory = ""

# Pattern to match all the CSV files you want to merge
csv_files = glob.glob(os.path.join(csv_directory, "output_jobs_with_details*.csv"))

# List to hold individual DataFrames
dfs = []

for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)

# Concatenate all DataFrames
merged_df = pd.concat(dfs, ignore_index=True)

# Write out to a single CSV file
merged_df.to_csv("merged_output_jobs_with_details.csv", index=False)

print("Merged CSV saved as merged_output_jobs_with_details.csv")

# %% [markdown]
# ### Create improved resume using GPT
